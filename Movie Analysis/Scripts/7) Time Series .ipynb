# %% [markdown]
# ### 1) Importing Library and Dataframe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from datetime import datetime
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.

# %%
# Importing movies_modified_3.csv dataframe

path = r'/Users/matthewabrams/Desktop/Movie Analysis'

movies = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'movies_modified_3.csv'), index_col = False)

movies.drop(columns = 'Unnamed: 0', inplace = True)

movies
# Out:
#                                                 name rating  unknown rating  \
# 0                                        The Shining      R           False
# 1                                    The Blue Lagoon      R           False
# 2     Star Wars: Episode V - The Empire Strikes Back     PG           False
# 3                                          Airplane!     PG           False
# 4                                         Caddyshack      R           False
# ...                                              ...    ...             ...
# 7663                                    More to Life    NaN            True
# 7664                                     Dream Round    NaN            True
# 7665                                   Saving Mbango    NaN            True
# 7666                                    It's Just Us    NaN            True
# 7667                                       Tee em el    NaN            True
#
#           genre  year  IMDb score  average IMDb score for country per film  \
# 0         Drama  1980         8.4                                      6.4
# 1     Adventure  1980         5.8                                      6.4
# 2        Action  1980         8.7                                      6.4
# 3        Comedy  1980         7.7                                      6.4
# 4        Comedy  1980         7.3                                      6.4
# ...         ...   ...         ...                                      ...
# 7663      Drama  2020         3.1                                      6.4
# 7664     Comedy  2020         4.7                                      6.4
# 7665      Drama  2020         5.7                                      5.7
# 7666      Drama  2020         6.4                                      6.4
# 7667     Horror  2020         5.7                                      6.4
#
#           votes  average number of votes for country per film  \
# 0      927000.0                                   95064.85761
# 1       65000.0                                   95064.85761
# 2     1200000.0                                   95064.85761
# 3      221000.0                                   95064.85761
# 4      108000.0                                   95064.85761
# ...         ...                                           ...
# 7663       18.0                                   95064.85761
# 7664       36.0                                   95064.85761
# 7665       29.0                                      29.00000
# 7666    33000.0                                   95064.85761
# 7667        7.0                                   95064.85761
#
#              director  ...        gross  average gross for country per film  \
# 0     Stanley Kubrick  ...   46998772.0                         86317303.02
# 1      Randal Kleiser  ...   58853106.0                         86317303.02
# 2      Irvin Kershner  ...  538375067.0                         86317303.02
# 3        Jim Abrahams  ...   83453539.0                         86317303.02
# 4        Harold Ramis  ...   39846344.0                         86317303.02
# ...               ...  ...          ...                                 ...
# 7663    Joseph Ebanks  ...   20205757.0                         86317303.02
# 7664     Dusty Dukatz  ...   20205757.0                         86317303.02
# 7665     Nkanya Nkwai  ...   20205757.0                         20205757.00
# 7666    James Randall  ...   20205757.0                         86317303.02
# 7667     Pereko Mosia  ...   20205757.0                         86317303.02
#
#            profit  average profit for country per film gross category  \
# 0      27998772.0                          52914083.47       20-100 M
# 1      54353106.0                          52914083.47       20-100 M
# 2     520375067.0                          52914083.47        > 100 M
# 3      79953539.0                          52914083.47       20-100 M
# 4      33846344.0                          52914083.47       20-100 M
# ...           ...                                  ...            ...
# 7663   20198757.0                          52914083.47       20-100 M
# 7664    -294243.0                          52914083.47       20-100 M
# 7665   20147007.0                          20147007.00       20-100 M
# 7666   20190757.0                          52914083.47       20-100 M
# 7667    -294243.0                          52914083.47       20-100 M
#
#                         company  unknown company  duration (in min)  \
# 0                  Warner Bros.            False              146.0
# 1             Columbia Pictures            False              104.0
# 2                     Lucasfilm            False              124.0
# 3            Paramount Pictures            False               88.0
# 4                Orion Pictures            False               98.0
# ...                         ...              ...                ...
# 7663                        NaN             True               90.0
# 7664  Cactus Blue Entertainment            False               90.0
# 7665           Embi Productions            False              104.0
# 7666                        NaN             True              120.0
# 7667                Pk 65 Films            False              102.0
#
#       released date  unknown released date
# 0        1980-06-13                  False
# 1        1980-07-02                  False
# 2        1980-06-20                  False
# 3        1980-07-02                  False
# 4        1980-07-25                  False
# ...             ...                    ...
# 7663     2020-10-23                  False
# 7664     2020-02-07                  False
# 7665     2020-04-27                  False
# 7666     2020-10-01                  False
# 7667     2020-08-19                  False
#
# [7668 rows x 28 columns]

# %% [markdown]
# ### 2) Subsetting and Data Wrangling

# %%
# Performing a time series analysis on all films released each year specifically from the US. 
# I need to create a subset which firstly filters out films which aren't from the US.

# %%
# Subset of dataframe returning values where country is United States

movies_us = movies[movies['country']=='United States']
movies_us
# Out:
#                                                 name rating  unknown rating  \
# 0                                        The Shining      R           False
# 1                                    The Blue Lagoon      R           False
# 2     Star Wars: Episode V - The Empire Strikes Back     PG           False
# 3                                          Airplane!     PG           False
# 4                                         Caddyshack      R           False
# ...                                              ...    ...             ...
# 7662                                   The Robinsons    NaN            True
# 7663                                    More to Life    NaN            True
# 7664                                     Dream Round    NaN            True
# 7666                                    It's Just Us    NaN            True
# 7667                                       Tee em el    NaN            True
#
#           genre  year  IMDb score  average IMDb score for country per film  \
# 0         Drama  1980         8.4                                      6.4
# 1     Adventure  1980         5.8                                      6.4
# 2        Action  1980         8.7                                      6.4
# 3        Comedy  1980         7.7                                      6.4
# 4        Comedy  1980         7.3                                      6.4
# ...         ...   ...         ...                                      ...
# 7662     Action  2020         6.4                                      6.4
# 7663      Drama  2020         3.1                                      6.4
# 7664     Comedy  2020         4.7                                      6.4
# 7666      Drama  2020         6.4                                      6.4
# 7667     Horror  2020         5.7                                      6.4
#
#           votes  average number of votes for country per film  \
# 0      927000.0                                   95064.85761
# 1       65000.0                                   95064.85761
# 2     1200000.0                                   95064.85761
# 3      221000.0                                   95064.85761
# 4      108000.0                                   95064.85761
# ...         ...                                           ...
# 7662    33000.0                                   95064.85761
# 7663       18.0                                   95064.85761
# 7664       36.0                                   95064.85761
# 7666    33000.0                                   95064.85761
# 7667        7.0                                   95064.85761
#
#              director  ...        gross  average gross for country per film  \
# 0     Stanley Kubrick  ...   46998772.0                         86317303.02
# 1      Randal Kleiser  ...   58853106.0                         86317303.02
# 2      Irvin Kershner  ...  538375067.0                         86317303.02
# 3        Jim Abrahams  ...   83453539.0                         86317303.02
# 4        Harold Ramis  ...   39846344.0                         86317303.02
# ...               ...  ...          ...                                 ...
# 7662        Directors  ...   20205757.0                         86317303.02
# 7663    Joseph Ebanks  ...   20205757.0                         86317303.02
# 7664     Dusty Dukatz  ...   20205757.0                         86317303.02
# 7666    James Randall  ...   20205757.0                         86317303.02
# 7667     Pereko Mosia  ...   20205757.0                         86317303.02
#
#            profit  average profit for country per film gross category  \
# 0      27998772.0                          52914083.47       20-100 M
# 1      54353106.0                          52914083.47       20-100 M
# 2     520375067.0                          52914083.47        > 100 M
# 3      79953539.0                          52914083.47       20-100 M
# 4      33846344.0                          52914083.47       20-100 M
# ...           ...                                  ...            ...
# 7662   20195757.0                          52914083.47       20-100 M
# 7663   20198757.0                          52914083.47       20-100 M
# 7664    -294243.0                          52914083.47       20-100 M
# 7666   20190757.0                          52914083.47       20-100 M
# 7667    -294243.0                          52914083.47       20-100 M
#
#                         company  unknown company  duration (in min)  \
# 0                  Warner Bros.            False              146.0
# 1             Columbia Pictures            False              104.0
# 2                     Lucasfilm            False              124.0
# 3            Paramount Pictures            False               88.0
# 4                Orion Pictures            False               98.0
# ...                         ...              ...                ...
# 7662                        NaN             True               90.0
# 7663                        NaN             True               90.0
# 7664  Cactus Blue Entertainment            False               90.0
# 7666                        NaN             True              120.0
# 7667                Pk 65 Films            False              102.0
#
#       released date  unknown released date
# 0        1980-06-13                  False
# 1        1980-07-02                  False
# 2        1980-06-20                  False
# 3        1980-07-02                  False
# 4        1980-07-25                  False
# ...             ...                    ...
# 7662     2020-11-10                  False
# 7663     2020-10-23                  False
# 7664     2020-02-07                  False
# 7666     2020-10-01                  False
# 7667     2020-08-19                  False
#
# [6735 rows x 28 columns]

# %%
movies_us.columns
# Out:
# Index(['name', 'rating', 'unknown rating', 'genre', 'year', 'IMDb score',
#        'average IMDb score for country per film', 'votes',
#        'average number of votes for country per film', 'director', 'writer',
#        'unknown writer', 'star', 'unknown star', 'country', 'unknown country',
#        'budget', 'average budget for country per film', 'gross',
#        'average gross for country per film', 'profit',
#        'average profit for country per film', 'gross category', 'company',
#        'unknown company', 'duration (in min)', 'released date',
#        'unknown released date'],
#       dtype='object')

# %%
# Focusing on two columns of dataframe: 'year' and 'profit'

profit_year = movies_us[['year', 'profit']]
profit_year
# Out:
#       year       profit
# 0     1980   27998772.0
# 1     1980   54353106.0
# 2     1980  520375067.0
# 3     1980   79953539.0
# 4     1980   33846344.0
# ...    ...          ...
# 7662  2020   20195757.0
# 7663  2020   20198757.0
# 7664  2020    -294243.0
# 7666  2020   20190757.0
# 7667  2020    -294243.0
#
# [6735 rows x 2 columns]

# %%
# Get average of profit earnings per year
profit_year = profit_year.groupby('year')['profit'].mean()
profit_year
# Out:
# year
# 1980    1.458296e+07
# 1981    1.037465e+07
# 1982    1.372142e+07
# 1983    8.995819e+06
# 1984    7.342482e+06
# 1985    5.071412e+06
# 1986    4.073910e+06
# 1987    6.828374e+06
# 1988    1.047792e+07
# 1989    1.576147e+07
# 1990    1.761649e+07
# 1991    1.438656e+07
# 1992    1.948027e+07
# 1993    2.355436e+07
# 1994    2.331699e+07
# 1995    2.390547e+07
# 1996    2.339717e+07
# 1997    3.727209e+07
# 1998    2.958475e+07
# 1999    3.843698e+07
# 2000    4.194246e+07
# 2001    5.246055e+07
# 2002    6.090004e+07
# 2003    6.387768e+07
# 2004    6.554963e+07
# 2005    5.900726e+07
# 2006    6.202171e+07
# 2007    7.344373e+07
# 2008    8.162949e+07
# 2009    9.310110e+07
# 2010    1.021333e+08
# 2011    1.144188e+08
# 2012    1.182459e+08
# 2013    1.126430e+08
# 2014    1.059418e+08
# 2015    1.074876e+08
# 2016    1.085407e+08
# 2017    1.132830e+08
# 2018    1.165539e+08
# 2019    1.194546e+08
# 2020    8.620608e+07
# Name: profit, dtype: float64

# %%
# Making the last line of code into a custom dataframe

profit_year = pd.DataFrame(profit_year)
profit_year
# Out:
#             profit
# year
# 1980  1.458296e+07
# 1981  1.037465e+07
# 1982  1.372142e+07
# 1983  8.995819e+06
# 1984  7.342482e+06
# 1985  5.071412e+06
# 1986  4.073910e+06
# 1987  6.828374e+06
# 1988  1.047792e+07
# 1989  1.576147e+07
# 1990  1.761649e+07
# 1991  1.438656e+07
# 1992  1.948027e+07
# 1993  2.355436e+07
# 1994  2.331699e+07
# 1995  2.390547e+07
# 1996  2.339717e+07
# 1997  3.727209e+07
# 1998  2.958475e+07
# 1999  3.843698e+07
# 2000  4.194246e+07
# 2001  5.246055e+07
# 2002  6.090004e+07
# 2003  6.387768e+07
# 2004  6.554963e+07
# 2005  5.900726e+07
# 2006  6.202171e+07
# 2007  7.344373e+07
# 2008  8.162949e+07
# 2009  9.310110e+07
# 2010  1.021333e+08
# 2011  1.144188e+08
# 2012  1.182459e+08
# 2013  1.126430e+08
# 2014  1.059418e+08
# 2015  1.074876e+08
# 2016  1.085407e+08
# 2017  1.132830e+08
# 2018  1.165539e+08
# 2019  1.194546e+08
# 2020  8.620608e+07

# %%
# Reset index

profit_year = profit_year.reset_index()

# %%
# Create a datetime column from 'year'
# Set the datetime as the index of the dataframe
# pd.offsets.YearEnd() will return the last day of the year instead of the first year

profit_year['datetime'] = pd.to_datetime(profit_year['year'], format='%Y') + pd.offsets.YearEnd()
profit_year = profit_year.set_index('datetime') 
profit_year
# Out:
#             year        profit
# datetime
# 1980-12-31  1980  1.458296e+07
# 1981-12-31  1981  1.037465e+07
# 1982-12-31  1982  1.372142e+07
# 1983-12-31  1983  8.995819e+06
# 1984-12-31  1984  7.342482e+06
# 1985-12-31  1985  5.071412e+06
# 1986-12-31  1986  4.073910e+06
# 1987-12-31  1987  6.828374e+06
# 1988-12-31  1988  1.047792e+07
# 1989-12-31  1989  1.576147e+07
# 1990-12-31  1990  1.761649e+07
# 1991-12-31  1991  1.438656e+07
# 1992-12-31  1992  1.948027e+07
# 1993-12-31  1993  2.355436e+07
# 1994-12-31  1994  2.331699e+07
# 1995-12-31  1995  2.390547e+07
# 1996-12-31  1996  2.339717e+07
# 1997-12-31  1997  3.727209e+07
# 1998-12-31  1998  2.958475e+07
# 1999-12-31  1999  3.843698e+07
# 2000-12-31  2000  4.194246e+07
# 2001-12-31  2001  5.246055e+07
# 2002-12-31  2002  6.090004e+07
# 2003-12-31  2003  6.387768e+07
# 2004-12-31  2004  6.554963e+07
# 2005-12-31  2005  5.900726e+07
# 2006-12-31  2006  6.202171e+07
# 2007-12-31  2007  7.344373e+07
# 2008-12-31  2008  8.162949e+07
# 2009-12-31  2009  9.310110e+07
# 2010-12-31  2010  1.021333e+08
# 2011-12-31  2011  1.144188e+08
# 2012-12-31  2012  1.182459e+08
# 2013-12-31  2013  1.126430e+08
# 2014-12-31  2014  1.059418e+08
# 2015-12-31  2015  1.074876e+08
# 2016-12-31  2016  1.085407e+08
# 2017-12-31  2017  1.132830e+08
# 2018-12-31  2018  1.165539e+08
# 2019-12-31  2019  1.194546e+08
# 2020-12-31  2020  8.620608e+07

# %%
# Creating a moving average column
# rolling(5).mean() will represent the five-year moving average regarding profit earnings

profit_year['five-year moving average'] = profit_year['profit'].rolling(5).mean()
profit_year.head(10)
# Out:
#             year        profit  five-year moving average
# datetime
# 1980-12-31  1980  1.458296e+07                       NaN
# 1981-12-31  1981  1.037465e+07                       NaN
# 1982-12-31  1982  1.372142e+07                       NaN
# 1983-12-31  1983  8.995819e+06                       NaN
# 1984-12-31  1984  7.342482e+06              1.100347e+07
# 1985-12-31  1985  5.071412e+06              9.101156e+06
# 1986-12-31  1986  4.073910e+06              7.841008e+06
# 1987-12-31  1987  6.828374e+06              6.462399e+06
# 1988-12-31  1988  1.047792e+07              6.758820e+06
# 1989-12-31  1989  1.576147e+07              8.442617e+06

# %%
# Drop year column

profit_year.drop(['year'], axis = 1, inplace=True)

# %%
profit_year
# Out:
#                   profit  five-year moving average
# datetime
# 1980-12-31  1.458296e+07                       NaN
# 1981-12-31  1.037465e+07                       NaN
# 1982-12-31  1.372142e+07                       NaN
# 1983-12-31  8.995819e+06                       NaN
# 1984-12-31  7.342482e+06              1.100347e+07
# 1985-12-31  5.071412e+06              9.101156e+06
# 1986-12-31  4.073910e+06              7.841008e+06
# 1987-12-31  6.828374e+06              6.462399e+06
# 1988-12-31  1.047792e+07              6.758820e+06
# 1989-12-31  1.576147e+07              8.442617e+06
# 1990-12-31  1.761649e+07              1.095163e+07
# 1991-12-31  1.438656e+07              1.301416e+07
# 1992-12-31  1.948027e+07              1.554454e+07
# 1993-12-31  2.355436e+07              1.815983e+07
# 1994-12-31  2.331699e+07              1.967093e+07
# 1995-12-31  2.390547e+07              2.092873e+07
# 1996-12-31  2.339717e+07              2.273085e+07
# 1997-12-31  3.727209e+07              2.628921e+07
# 1998-12-31  2.958475e+07              2.749529e+07
# 1999-12-31  3.843698e+07              3.051929e+07
# 2000-12-31  4.194246e+07              3.412669e+07
# 2001-12-31  5.246055e+07              3.993937e+07
# 2002-12-31  6.090004e+07              4.466496e+07
# 2003-12-31  6.387768e+07              5.152354e+07
# 2004-12-31  6.554963e+07              5.694607e+07
# 2005-12-31  5.900726e+07              6.035903e+07
# 2006-12-31  6.202171e+07              6.227126e+07
# 2007-12-31  7.344373e+07              6.478000e+07
# 2008-12-31  8.162949e+07              6.833037e+07
# 2009-12-31  9.310110e+07              7.384066e+07
# 2010-12-31  1.021333e+08              8.246588e+07
# 2011-12-31  1.144188e+08              9.294530e+07
# 2012-12-31  1.182459e+08              1.019057e+08
# 2013-12-31  1.126430e+08              1.081084e+08
# 2014-12-31  1.059418e+08              1.106766e+08
# 2015-12-31  1.074876e+08              1.117474e+08
# 2016-12-31  1.085407e+08              1.105718e+08
# 2017-12-31  1.132830e+08              1.095792e+08
# 2018-12-31  1.165539e+08              1.103614e+08
# 2019-12-31  1.194546e+08              1.130640e+08
# 2020-12-31  8.620608e+07              1.088077e+08

# %% [markdown]
# ### 3) Plotting the subset

# %%
# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi = 300)
plt.plot(profit_year.index, profit_year['profit'], linewidth = 3, color = 'green')
plt.plot(profit_year.index, profit_year['five-year moving average'], linewidth = 3, color = 'orange')
plt.title('Average Profit of Films Released in US Per Year (1980-2020)', fontsize = 12, fontweight = 'bold')
plt.xlabel('Date', fontsize = 10, fontweight = 'bold')
plt.ylabel('Profit', fontsize = 10, fontweight = 'bold')
plt.legend(('profit', 'five-year moving average'))

# %%
# Average profit in release of films in US have steadily increased
# Average profit has peaked around 2019
# After 2020 started, average profit started to plummet

# %% [markdown]
# ### 4) Time-series analysis: decomposition for profit column

# %%
profit = profit_year
profit
# Out:
#                   profit  five-year moving average
# datetime
# 1980-12-31  1.458296e+07                       NaN
# 1981-12-31  1.037465e+07                       NaN
# 1982-12-31  1.372142e+07                       NaN
# 1983-12-31  8.995819e+06                       NaN
# 1984-12-31  7.342482e+06              1.100347e+07
# 1985-12-31  5.071412e+06              9.101156e+06
# 1986-12-31  4.073910e+06              7.841008e+06
# 1987-12-31  6.828374e+06              6.462399e+06
# 1988-12-31  1.047792e+07              6.758820e+06
# 1989-12-31  1.576147e+07              8.442617e+06
# 1990-12-31  1.761649e+07              1.095163e+07
# 1991-12-31  1.438656e+07              1.301416e+07
# 1992-12-31  1.948027e+07              1.554454e+07
# 1993-12-31  2.355436e+07              1.815983e+07
# 1994-12-31  2.331699e+07              1.967093e+07
# 1995-12-31  2.390547e+07              2.092873e+07
# 1996-12-31  2.339717e+07              2.273085e+07
# 1997-12-31  3.727209e+07              2.628921e+07
# 1998-12-31  2.958475e+07              2.749529e+07
# 1999-12-31  3.843698e+07              3.051929e+07
# 2000-12-31  4.194246e+07              3.412669e+07
# 2001-12-31  5.246055e+07              3.993937e+07
# 2002-12-31  6.090004e+07              4.466496e+07
# 2003-12-31  6.387768e+07              5.152354e+07
# 2004-12-31  6.554963e+07              5.694607e+07
# 2005-12-31  5.900726e+07              6.035903e+07
# 2006-12-31  6.202171e+07              6.227126e+07
# 2007-12-31  7.344373e+07              6.478000e+07
# 2008-12-31  8.162949e+07              6.833037e+07
# 2009-12-31  9.310110e+07              7.384066e+07
# 2010-12-31  1.021333e+08              8.246588e+07
# 2011-12-31  1.144188e+08              9.294530e+07
# 2012-12-31  1.182459e+08              1.019057e+08
# 2013-12-31  1.126430e+08              1.081084e+08
# 2014-12-31  1.059418e+08              1.106766e+08
# 2015-12-31  1.074876e+08              1.117474e+08
# 2016-12-31  1.085407e+08              1.105718e+08
# 2017-12-31  1.132830e+08              1.095792e+08
# 2018-12-31  1.165539e+08              1.103614e+08
# 2019-12-31  1.194546e+08              1.130640e+08
# 2020-12-31  8.620608e+07              1.088077e+08

# %%
# Dropping five-year moving average column 

profit.drop(columns = 'five-year moving average', inplace = True)
profit
# Out:
#                   profit
# datetime
# 1980-12-31  1.458296e+07
# 1981-12-31  1.037465e+07
# 1982-12-31  1.372142e+07
# 1983-12-31  8.995819e+06
# 1984-12-31  7.342482e+06
# 1985-12-31  5.071412e+06
# 1986-12-31  4.073910e+06
# 1987-12-31  6.828374e+06
# 1988-12-31  1.047792e+07
# 1989-12-31  1.576147e+07
# 1990-12-31  1.761649e+07
# 1991-12-31  1.438656e+07
# 1992-12-31  1.948027e+07
# 1993-12-31  2.355436e+07
# 1994-12-31  2.331699e+07
# 1995-12-31  2.390547e+07
# 1996-12-31  2.339717e+07
# 1997-12-31  3.727209e+07
# 1998-12-31  2.958475e+07
# 1999-12-31  3.843698e+07
# 2000-12-31  4.194246e+07
# 2001-12-31  5.246055e+07
# 2002-12-31  6.090004e+07
# 2003-12-31  6.387768e+07
# 2004-12-31  6.554963e+07
# 2005-12-31  5.900726e+07
# 2006-12-31  6.202171e+07
# 2007-12-31  7.344373e+07
# 2008-12-31  8.162949e+07
# 2009-12-31  9.310110e+07
# 2010-12-31  1.021333e+08
# 2011-12-31  1.144188e+08
# 2012-12-31  1.182459e+08
# 2013-12-31  1.126430e+08
# 2014-12-31  1.059418e+08
# 2015-12-31  1.074876e+08
# 2016-12-31  1.085407e+08
# 2017-12-31  1.132830e+08
# 2018-12-31  1.165539e+08
# 2019-12-31  1.194546e+08
# 2020-12-31  8.620608e+07

# %%
# Decompose the time series using an additive model

decomposition = sm.tsa.seasonal_decompose(profit, model='additive')

# %%
# Define a fixed size for all special charts
from pylab import rcParams 

rcParams['figure.figsize'] = 18, 7

# %%
# Plot separate components
decomposition.plot()
plt.show()

# %% [markdown]
# ### 5) Testing for stationarity

# %%
# The null hypothesis in this case would be the presence of a unit root 
# Want to disprove that there’s a unit root, which would mean that the data is stationary

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return an array of numbers 
# This is why you need to also define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(profit['profit'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -3.531220
# p-value                         0.007221
# Number of Lags Used            10.000000
# Number of Observations Used    30.000000
# Critical Value (1%)            -3.669920
# Critical Value (5%)            -2.964071
# Critical Value (10%)           -2.621171
# dtype: float64

# %%
# Test statistic is smaller than the critical value at both the five and ten percent significance levels. 
# There's also a satisfactory p-value (p < 0.05). 
# We can reject the null hypothesis and, as a result, consider the series stationary.

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # Here, you import the autocorrelation and partial correlation plots

plot_acf(profit)
plt.show()

# %%
# There are 5 vertical lines above the confidence interval or 5 significant lags. 
# Since it's less than 10 significant lags, the minimum amount of lags for a round of differencing, there's no need to conduct it.
# Despite the Dickey-Fuller test saying that the data is stationary, the stationarity is moderately strong

# %% [markdown]
# ### 6) Strengthening the stationarity of the data for profit column

# %%
# Strengthing the strength of the stationarity of the data using differencing method

data_diff = profit - profit.shift(1)
data_diff
# Out:
#                   profit
# datetime
# 1980-12-31           NaN
# 1981-12-31 -4.208307e+06
# 1982-12-31  3.346765e+06
# 1983-12-31 -4.725598e+06
# 1984-12-31 -1.653337e+06
# 1985-12-31 -2.271070e+06
# 1986-12-31 -9.975015e+05
# 1987-12-31  2.754464e+06
# 1988-12-31  3.649549e+06
# 1989-12-31  5.283545e+06
# 1990-12-31  1.855018e+06
# 1991-12-31 -3.229923e+06
# 1992-12-31  5.093706e+06
# 1993-12-31  4.074089e+06
# 1994-12-31 -2.373696e+05
# 1995-12-31  5.884788e+05
# 1996-12-31 -5.082985e+05
# 1997-12-31  1.387492e+07
# 1998-12-31 -7.687336e+06
# 1999-12-31  8.852230e+06
# 2000-12-31  3.505481e+06
# 2001-12-31  1.051809e+07
# 2002-12-31  8.439489e+06
# 2003-12-31  2.977637e+06
# 2004-12-31  1.671950e+06
# 2005-12-31 -6.542364e+06
# 2006-12-31  3.014445e+06
# 2007-12-31  1.142202e+07
# 2008-12-31  8.185761e+06
# 2009-12-31  1.147160e+07
# 2010-12-31  9.032250e+06
# 2011-12-31  1.228549e+07
# 2012-12-31  3.827087e+06
# 2013-12-31 -5.602970e+06
# 2014-12-31 -6.701195e+06
# 2015-12-31  1.545865e+06
# 2016-12-31  1.053122e+06
# 2017-12-31  4.742280e+06
# 2018-12-31  3.270845e+06
# 2019-12-31  2.900730e+06
# 2020-12-31 -3.324852e+07

# %%
# Dropping na values in order to perform the Dickey-Fuller Stationarity test

data_diff.dropna(inplace = True)
data_diff
# Out:
#                   profit
# datetime
# 1981-12-31 -4.208307e+06
# 1982-12-31  3.346765e+06
# 1983-12-31 -4.725598e+06
# 1984-12-31 -1.653337e+06
# 1985-12-31 -2.271070e+06
# 1986-12-31 -9.975015e+05
# 1987-12-31  2.754464e+06
# 1988-12-31  3.649549e+06
# 1989-12-31  5.283545e+06
# 1990-12-31  1.855018e+06
# 1991-12-31 -3.229923e+06
# 1992-12-31  5.093706e+06
# 1993-12-31  4.074089e+06
# 1994-12-31 -2.373696e+05
# 1995-12-31  5.884788e+05
# 1996-12-31 -5.082985e+05
# 1997-12-31  1.387492e+07
# 1998-12-31 -7.687336e+06
# 1999-12-31  8.852230e+06
# 2000-12-31  3.505481e+06
# 2001-12-31  1.051809e+07
# 2002-12-31  8.439489e+06
# 2003-12-31  2.977637e+06
# 2004-12-31  1.671950e+06
# 2005-12-31 -6.542364e+06
# 2006-12-31  3.014445e+06
# 2007-12-31  1.142202e+07
# 2008-12-31  8.185761e+06
# 2009-12-31  1.147160e+07
# 2010-12-31  9.032250e+06
# 2011-12-31  1.228549e+07
# 2012-12-31  3.827087e+06
# 2013-12-31 -5.602970e+06
# 2014-12-31 -6.701195e+06
# 2015-12-31  1.545865e+06
# 2016-12-31  1.053122e+06
# 2017-12-31  4.742280e+06
# 2018-12-31  3.270845e+06
# 2019-12-31  2.900730e+06
# 2020-12-31 -3.324852e+07

# %%
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -3.510389
# p-value                         0.007724
# Number of Lags Used             0.000000
# Number of Observations Used    39.000000
# Critical Value (1%)            -3.610400
# Critical Value (5%)            -2.939109
# Critical Value (10%)           -2.608063
# dtype: float64

# %%
# Test statistic is smaller than the critical value at both the five and ten percent significance levels. 
# There's also a satisfactory p-value (p < 0.05).

# %%
plot_acf(data_diff)
plt.show()

# %%
# Using the differencing method, there is 1 vertical line above the confidence interval or 1 significant lag.

# %%
profit.to_csv(os.path.join(path, 'Data', 'Prepared Data', 'profit.csv'))
